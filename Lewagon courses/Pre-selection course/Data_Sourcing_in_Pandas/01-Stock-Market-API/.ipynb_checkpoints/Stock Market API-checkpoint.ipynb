# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "http://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

apple_stock_df = pd.DataFrame(api_data)
apple_stock_df
# Out:
#           date    open   close    high     low     volume   uOpen  uClose  \
# 0   2020-07-06   92.50   93.46   93.95   92.47  118655652  370.00  373.85
# 1   2020-07-07   93.85   93.17   94.66   93.06  112424456  375.41  372.69
# 2   2020-07-08   94.18   95.34   95.38   94.09  117091880  376.72  381.37
# 3   2020-07-09   96.26   95.68   96.32   94.67  125642608  385.05  382.73
# 4   2020-07-10   95.34   95.92   95.98   94.71   90257320  381.34  383.68
# ..         ...     ...     ...     ...     ...        ...     ...     ...
# 60  2020-09-29  114.55  114.09  115.31  113.57  100060526  114.55  114.09
# 61  2020-09-30  113.79  115.81  117.26  113.62  142675184  113.79  115.81
# 62  2020-10-01  117.64  116.79  117.72  115.83  116120440  117.64  116.79
# 63  2020-10-02  112.89  113.02  115.37  112.22  144711986  112.89  113.02
# 64  2020-10-05  113.91  116.50  116.65  113.55  106243839  113.91  116.50
#
#      uHigh    uLow    uVolume  change  changePercent       label  \
# 0   375.78  369.87   29663913    0.00         0.0000   Jul 6, 20
# 1   378.62  372.23   28106114   -0.29        -0.3103   Jul 7, 20
# 2   381.50  376.36   29272970    2.17         2.3290   Jul 8, 20
# 3   385.27  378.69   31410652    0.34         0.3566   Jul 9, 20
# 4   383.92  378.82   22564330    0.24         0.2482  Jul 10, 20
# ..     ...     ...        ...     ...            ...         ...
# 60  115.31  113.57  100060526   -0.87        -0.7568  Sep 29, 20
# 61  117.26  113.62  142675184    1.72         1.5076  Sep 30, 20
# 62  117.72  115.83  116120440    0.98         0.8462   Oct 1, 20
# 63  115.37  112.22  144711986   -3.77        -3.2280   Oct 2, 20
# 64  116.65  113.55  106243839    3.48         2.9900   Oct 5, 20
#
#     changeOverTime
# 0         0.000000
# 1        -0.003103
# 2         0.020115
# 3         0.023753
# 4         0.026294
# ..             ...
# 60        0.220703
# 61        0.239107
# 62        0.249592
# 63        0.209255
# 64        0.000000
#
# [65 rows x 15 columns]

# %%
#Convert the date column to a datetime object
apple_stock_df.date = pd.to_datetime(apple_stock_df.date, format="%Y-%m-%d")

# %%
apple_stock_df.head()
# Out:
#         date   open  close   high    low     volume   uOpen  uClose   uHigh  \
# 0 2020-07-06  92.50  93.46  93.95  92.47  118655652  370.00  373.85  375.78
# 1 2020-07-07  93.85  93.17  94.66  93.06  112424456  375.41  372.69  378.62
# 2 2020-07-08  94.18  95.34  95.38  94.09  117091880  376.72  381.37  381.50
# 3 2020-07-09  96.26  95.68  96.32  94.67  125642608  385.05  382.73  385.27
# 4 2020-07-10  95.34  95.92  95.98  94.71   90257320  381.34  383.68  383.92
#
#      uLow   uVolume  change  changePercent       label  changeOverTime
# 0  369.87  29663913    0.00         0.0000   Jul 6, 20        0.000000
# 1  372.23  28106114   -0.29        -0.3103   Jul 7, 20       -0.003103
# 2  376.36  29272970    2.17         2.3290   Jul 8, 20        0.020115
# 3  378.69  31410652    0.34         0.3566   Jul 9, 20        0.023753
# 4  378.82  22564330    0.24         0.2482  Jul 10, 20        0.026294

# %%
apple_stock_df.date.describe
# Out:
# <bound method NDFrame.describe of 0    2020-07-06
# 1    2020-07-07
# 2    2020-07-08
# 3    2020-07-09
# 4    2020-07-10
#         ...
# 60   2020-09-29
# 61   2020-09-30
# 62   2020-10-01
# 63   2020-10-02
# 64   2020-10-05
# Name: date, Length: 65, dtype: datetime64[ns]>

# %%
#Set the date column as the index

apple_stock_df.set_index('date', inplace=True)

# idem apple_stock_df = apple_stock_df.set_index('date')

apple_stock_df.head()
# Out:
#              open  close   high    low     volume   uOpen  uClose   uHigh  \
# date
# 2020-07-06  92.50  93.46  93.95  92.47  118655652  370.00  373.85  375.78
# 2020-07-07  93.85  93.17  94.66  93.06  112424456  375.41  372.69  378.62
# 2020-07-08  94.18  95.34  95.38  94.09  117091880  376.72  381.37  381.50
# 2020-07-09  96.26  95.68  96.32  94.67  125642608  385.05  382.73  385.27
# 2020-07-10  95.34  95.92  95.98  94.71   90257320  381.34  383.68  383.92
#
#               uLow   uVolume  change  changePercent       label  \
# date
# 2020-07-06  369.87  29663913    0.00         0.0000   Jul 6, 20
# 2020-07-07  372.23  28106114   -0.29        -0.3103   Jul 7, 20
# 2020-07-08  376.36  29272970    2.17         2.3290   Jul 8, 20
# 2020-07-09  378.69  31410652    0.34         0.3566   Jul 9, 20
# 2020-07-10  378.82  22564330    0.24         0.2482  Jul 10, 20
#
#             changeOverTime
# date
# 2020-07-06        0.000000
# 2020-07-07       -0.003103
# 2020-07-08        0.020115
# 2020-07-09        0.023753
# 2020-07-10        0.026294

# %%
apple_stock_df.close.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#figsize in inches (width, height)!

apple_stock_df[['open', 'close', 'high', 'low']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **What is the URL for the:**
#
# Amazon stock prices since last year?
# Facebook market cap?
# Apple research and development spendings quarterly?
# Last news about Tesla?
# Performance of the ‘Energy’ sector?

# %%
url2 = "http://iex.lewagon.com/stable/stock/amzn/chart/1y"
api_data = requests.get(url2).json()

amzn_stock_df = pd.DataFrame(api_data)
amzn_stock_df.date = pd.to_datetime(amzn_stock_df.date, format="%Y-%m-%d")
amzn_stock_df.set_index('date', inplace=True)
amzn_stock_df.close.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
url3 = "http://iex.lewagon.com/stable/stock/fb/quote/marketCap"
fb_mkt_cap = requests.get(url3).json()

fb_mkt_cap
# Out:
# 736874153711

# %%
url4 = "http://iex.lewagon.com/stable/stock/aapl/income/"
appl_financials = requests.get(url4).json()

appl_financials['income'][0]['researchAndDevelopment']

# appl_financials = pd.DataFrame(requests.get(url4).json()['income'])
# appl_financials[['researchAndDevelopment']]
# Out:
# 4758000000

# %%
url5 = "http://iex.lewagon.com/stable/stock/tsla/news/last/"
tsla_news = requests.get(url5).json()

tsla_news
# Out:
# [{'datetime': 1602038951000,
#   'headline': '3 Tesla Mining & Battery Developments',
#   'source': 'CleanTechnica',
#   'url': 'https://cloud.iexapis.com/v1/news/article/87e3c906-0837-476d-83b3-19a780ad2983',
#   'summary': "Reports on a few different matters on Tesla mining and batteries have been leaking out lately — since Battery Day, basically. We've covered a couple of them individually, but there are three that I'm looping together for one piece here",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/87e3c906-0837-476d-83b3-19a780ad2983',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602037034000,
#   'headline': "Tesla Fired Employee On Allegations Of 'Maliciously' Sabotaging Fremont Factory: Report",
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/ed5632cb-c932-4b8e-a5ab-33807e2cb3d2',
#   'summary': "Tesla Inc (NASDAQ: TSLA ) fired an employee for carrying out malicious activities at its manufacturing facility in Fremont, California last month, Bloomberg reported Tuesday. What Happened: In an internal memo, Al Prescott, Tesla’s vice president of legal and acting general counsel said the employee's actions at the Fremont factory led to the disruption of operations for a short period. “Two weeks ago, our IT and InfoSec teams determined than [sic] an employee had maliciously sabotaged a part … Full story available on Benzinga.com",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/ed5632cb-c932-4b8e-a5ab-33807e2cb3d2',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602035104000,
#   'headline': 'Tesla will Batteriekosten senken - und dazu Lithium selbst gewinnen',
#   'source': 'Finanzen AT',
#   'url': 'https://cloud.iexapis.com/v1/news/article/dc6b6d55-6495-437e-b5ca-059245a4d809',
#   'summary': '• Tesla beschäftigt sich mit Lithiumgewinnung • Cypress Development-Übernahme wohl vom Tisch • Tesla plant eigene Lithiumherstellung Lithium spielt für den E-Automarkt eine wichtige Rolle, da der Rohstoff für die Produktion der Batteriezellen benötigt wird. Da in der Automobilindustrie aktuell eine…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/dc6b6d55-6495-437e-b5ca-059245a4d809',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1602035100000,
#   'headline': 'Hyliion Electric Truck SPAC Mints 28 Year Old Billionaire CEO',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/17bd3fdf-a2d1-4bed-936c-665c2ae91bab',
#   'summary': 'Hyliion Electric Truck SPAC Mints 28 Year Old Billionaire CEO Tyler Durden Tue, 10/06/2020 - 21:45 Arising out of the smoke and rubble of Nikola\'s recent battle with short sellers, one electric truck company has casually made its way onto the public markets via a SPAC, making its 28 year old founder a billionaire in the process. Does it feel enough like 1999 yet? “We were fortunate on timing,” Hyliion Holdings Corp. CEO Thomas Healy told Bloomberg . His company, founded just 5 years ago in 2015, went public through a SPAC with Tortoise Acquisition Corporation and started trading publicly last Friday. Healy is now one of the world\'s youngest self-made billionaires. He started his company after watching Tesla while growing up and says that spurred an interest in electric vehicles. "I thought: Why do we have electric technology in cars and not in trucks yet, since trucks are where you can have the biggest impact?" he told Bloomberg. Healy had originally planned to go public at the time the coronavirus struck. “If we were trying to close right when the stock market was on that downswing, we might have been having different discussions,” he admitted.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/17bd3fdf-a2d1-4bed-936c-665c2ae91bab',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602033300000,
#   'headline': "Tesla's quarterly report could land Elon Musk another $3 billion",
#   'source': 'Business Standard',
#   'url': 'https://cloud.iexapis.com/v1/news/article/c0c15f6d-567c-404d-9c06-1711300c14c1',
#   'summary': 'Each tranche gives Musk the option to buy 8.44 million Tesla shares at $70 each, about a sixth of their current price',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/c0c15f6d-567c-404d-9c06-1711300c14c1',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602026100000,
#   'headline': 'Elon Musk says Tesla’s Full Self-Driving suite is coming to Japan',
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/be5028f1-f8f0-4731-a93d-5962c89a6eca',
#   'summary': 'Tesla’s Full Self-Driving suite is among the most sophisticated and advanced driver assistance systems in the world. As self-driving and semi-autonomous software is relatively new, many features have yet to be approved in markets outside of the United States. However, Elon Musk, the CEO of Tesla, indicated that the FSD suite would be making its […] The post Elon Musk says Tesla’s Full Self-Driving suite is coming to Japan appeared first on TESLARATI .',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/be5028f1-f8f0-4731-a93d-5962c89a6eca',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602025242000,
#   'headline': 'VIDEO — Simon Moores: Insights on Tesla, EV Supply Chains and Battery Metals',
#   'source': 'Investing News Network',
#   'url': 'https://cloud.iexapis.com/v1/news/article/5ed48ac4-b123-4895-94bc-29e418d5d366',
#   'summary': "INN caught up with Simon Moores of Benchmark Mineral Intelligence to talk all things battery metals after Tesla's Battery Day. The post VIDEO — Simon Moores: Insights on Tesla, EV Supply Chains and Battery Metals appeared first on Investing News Network .",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/5ed48ac4-b123-4895-94bc-29e418d5d366',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602023496000,
#   'headline': "Tesla employee fired for 'maliciously sabotaging' part of Fremont factory",
#   'source': 'Daily Mail Online',
#   'url': 'https://cloud.iexapis.com/v1/news/article/205e004b-39e2-4c05-866c-0103c55fee90',
#   'summary': "Tesla announced Tuesday that an employee was fired last month after he 'maliciously sabotaged' a part of a factory in Fremont, California.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/205e004b-39e2-4c05-866c-0103c55fee90',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602020042000,
#   'headline': 'Tesla, BHP In Talks For Nickel Supply Deal: Report',
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/27040356-84c2-43bf-a729-fed866f85895',
#   'summary': "On Tesla Inc's (NASDAQ: TSLA ) second-quarter earnings call, CEO Elon Musk asked nickel miners to ramp up mining operations. Tesla will need a lot more nickel if the company's plan for the new 4680 battery is to come to market and be mass produced. Tesla will be using nickel in high performance and long-lasting batteries for electric vehicles. Now, a … Full story available on Benzinga.com",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/27040356-84c2-43bf-a729-fed866f85895',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602017726000,
#   'headline': 'Tesla and BHP look to make Nickel supply deal: report',
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/db66525f-743e-4fc3-8022-f260bd0a5fab',
#   'summary': 'Tesla and high-volume nickel miner BHP are looking to come to terms in a deal that would see the mining company supply vast amounts of the metal to the electric automaker for EV batteries. Bloomberg reported on Tuesday that sources familiar with the matter know that BHP and Tesla are currently in talks, but the […] The post Tesla and BHP look to make Nickel supply deal: report appeared first on TESLARATI .',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/db66525f-743e-4fc3-8022-f260bd0a5fab',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
url6 = "http://iex.lewagon.com/stable/stock/market/sector-performance"
sector_performances = pd.DataFrame(requests.get(url6).json())

sector_performances[sector_performances['name']=='Energy']
# Out:
#      type    name  performance    lastUpdated
# 7  sector  Energy     -0.01491  1602014400025

# %%
stocks = ['goog', 'fb', 'amzn', 'aapl', 'meli']
stocks_data = pd.DataFrame(columns=['date']+stocks)
for stock in stocks:
    url = f"http://iex.lewagon.com/stable/stock/{stock}/chart/1y"
    api_data = pd.DataFrame(requests.get(url).json())
    stocks_data[['date', stock]] = api_data[['date', 'close']]
    
stocks_data.head()
# Out:
#          date     goog      fb     amzn   aapl    meli
# 0  2019-10-03  1187.83  179.38  1724.42  55.21  558.19
# 1  2019-10-04  1209.00  180.45  1739.65  56.75  559.22
# 2  2019-10-07  1207.68  179.68  1732.66  56.77  548.87
# 3  2019-10-08  1189.13  177.75  1705.51  56.10  525.63
# 4  2019-10-09  1202.31  179.85  1721.99  56.76  532.03

# %%
stocks_data.date = pd.to_datetime(stocks_data.date, format="%Y-%m-%d")
stocks_data.set_index('date', inplace=True)
stocks_data.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#normalization technique
def normalization(df):
    return df/df[0]

stocks_data = stocks_data.apply(normalization)

stocks_data.head()
# Out:
#                 goog        fb      amzn      aapl      meli
# date
# 2019-10-03  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-10-04  1.017822  1.005965  1.008832  1.027893  1.001845
# 2019-10-07  1.016711  1.001672  1.004778  1.028256  0.983303
# 2019-10-08  1.001094  0.990913  0.989034  1.016120  0.941669
# 2019-10-09  1.012190  1.002620  0.998591  1.028075  0.953134

# %%
stocks_data.plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='date'>
